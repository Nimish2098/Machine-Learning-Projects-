# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
data = pd.read_csv('economy.csv')
data.head(10)
# Out:
#   date   airline ch_code  num_code dep_time   from time_taken       stop  \
# 0  Fri  SpiceJet      SG      8709    18:55  Delhi    02h 10m  non-stop
# 1  Fri  SpiceJet      SG      8157    06:20  Delhi    02h 20m  non-stop
# 2  Fri   AirAsia      I5       764    04:25  Delhi    02h 10m  non-stop
# 3  Fri   Vistara      UK       995    10:20  Delhi    02h 15m  non-stop
# 4  Fri   Vistara      UK       963    08:50  Delhi    02h 20m  non-stop
# 5  Fri   Vistara      UK       945    11:40  Delhi    02h 20m  non-stop
# 6  Fri   Vistara      UK       927    09:30  Delhi    02h 05m  non-stop
# 7  Fri   Vistara      UK       951    14:20  Delhi    02h 10m  non-stop
# 8  Fri  GO FIRST      G8       334    08:00  Delhi    02h 10m  non-stop
# 9  Fri  GO FIRST      G8       336    14:20  Delhi    02h 15m  non-stop
#
#   arr_time      to  price
# 0    21:05  Mumbai  5,953
# 1    08:40  Mumbai  5,953
# 2    06:35  Mumbai  5,956
# 3    12:35  Mumbai  5,955
# 4    11:10  Mumbai  5,955
# ...

# %%
# converting 'dep_time' and 'arr_time' to minutes since midnight
def time_to_minutes(t):
    h,m = map(int,t.split(':'))
    return h*60+m

data['dep_time'] = data['dep_time'].apply(time_to_minutes)
data['arr_time'] = data['arr_time'].apply(time_to_minutes)

# %%
# convert 'time_taken' to total minutes
def convert_time_taken(tt):
    h,m = map(int, tt.replace('h','').replace('m','').split())
    return h*60+m

data['time_taken'] = data['time_taken'].apply(convert_time_taken)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 6
#       3     h,m = map(int, tt.replace('h','').replace('m','').split())
#       4     return h*60+m
# ----> 6 data['time_taken'] = data['time_taken'].apply(convert_time_taken)
#
# File C:\NPC\anaconda3\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# ...
